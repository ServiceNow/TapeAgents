# %%
import os

for fname in os.listdir("/mnt/llmd/results/exps/oleh/tapeagents/gaia/runs/gpt4o_mini_t02_3/tapes/"):
    l, r = fname.split("_task")
    n = int(r.split(".")[0])
    print(n, fname)
    if n < 10:
        newname = f"/mnt/llmd/results/exps/oleh/tapeagents/gaia/runs/gpt4o_mini_t02_3/tapes/{l}_task{n:02d}.json"
        os.rename(
            f"/mnt/llmd/results/exps/oleh/tapeagents/gaia/runs/gpt4o_mini_t02_3/tapes/{fname}",
            newname,
        )
# Out:
# 9 l2_task9.json
# 29 l2_task29.json
# 83 l2_task83.json
# 3 l1_task3.json
# 15 l1_task15.json
# 53 l2_task53.json
# 19 l3_task19.json
# 46 l1_task46.json
# 7 l2_task7.json
# 27 l2_task27.json
# 1 l3_task1.json
# 17 l3_task17.json
# 48 l1_task48.json
# 32 l1_task32.json
# 74 l2_task74.json
# 34 l2_task34.json
# 21 l1_task21.json
# 67 l2_task67.json
# 40 l2_task40.json
# 69 l2_task69.json
# 23 l3_task23.json
# 13 l2_task13.json
# 21 l3_task21.json
# 11 l2_task11.json
# 42 l2_task42.json
# 38 l2_task38.json
# 23 l1_task23.json
# 65 l2_task65.json
# 36 l2_task36.json
# 30 l1_task30.json
# 76 l2_task76.json
# 5 l2_task5.json
# 25 l2_task25.json
# 19 l1_task19.json
# 3 l3_task3.json
# 15 l3_task15.json
# 44 l1_task44.json
# 78 l2_task78.json
# 81 l2_task81.json
# 1 l1_task1.json
# 17 l1_task17.json
# 51 l2_task51.json
# 37 l2_task37.json
# 22 l1_task22.json
# 64 l2_task64.json
# 43 l2_task43.json
# 39 l2_task39.json
# 20 l3_task20.json
# 10 l2_task10.json
# 80 l2_task80.json
# ...
